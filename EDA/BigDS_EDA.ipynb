# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Big Dataset EDA

# %% [markdown]
# ## Read data from csv file

# %%
BigDS = pd.read_csv('../Dataset/big_dataset.csv', index_col=[0])

# %% [markdown]
# ## Basic infomation about dataset

# %%
BigDS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9808 entries, 0 to 9807
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     9364 non-null   float64
#  1   Area      8561 non-null   float64
#  2   Location  5495 non-null   object
# dtypes: float64(2), object(1)
# memory usage: 306.5+ KB

# %%
BigDS.isna().sum()
# Out:
# Price        444
# Area        1247
# Location    4313
# dtype: int64

# %%
BigDS.head()
# Out:
#        Price  Area       Location
# 0  2000000.0  35.0       Hòa Minh
# 1  2500000.0  35.0          Mỹ An
# 2  2000000.0  35.0  Hòa Cường Nam
# 3  1700000.0  20.0        Xuân Hà
# 4  2200000.0  18.0  Hòa Cường Bắc

# %% [markdown]
# ## Visualize distribution of Area values

# %%
plt.figure(figsize=(12, 4))
sns.boxplot(data=BigDS, x='Area')
# Out:
# <Axes: xlabel='Area'>

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=BigDS, x='Area', y='Location')
# Out:
# <Axes: xlabel='Area', ylabel='Location'>

# %% [markdown]
# ## Visualize distribution of Price values

# %%
plt.figure(figsize=(12, 4))
sns.boxplot(data=BigDS, x='Price')
# Out:
# <Axes: xlabel='Price'>

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=BigDS, x='Price', y='Location')
# Out:
# <Axes: xlabel='Price', ylabel='Location'>

# %% [markdown]
# The majority of the data points are clustered closely together with a low spread
#
# It is hard to see the distribution of the data since the outliers is extremely large
#
# There are a few values (outliers) much larger than the rest of data

# %% [markdown]
# ## Correlation matrix

# %%
dataset_new = BigDS.copy()
lbe = LabelEncoder()
dataset_new['Location'] = lbe.fit_transform(dataset_new['Location'])
sns.heatmap(data=dataset_new.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# From the correlation matrix, we can draw the following conclusions:
#
# * Price and Area: There is a positive correlation between Price and Area. This indicates that as the Area increases, the Price tends to increase as well, although the correlation is not very strong.
#
# * Price and Ward: There is a weak negative correlation between Price and Ward. This suggests that there is a very slight tendency for the Price to change as the Ward value changes, but the correlation is too weak to make any significant conclusions.
#
# * Area and Ward: There is a very weak positive correlation between Area and Ward. This implies that there is a slight tendency for the Area to change as the Ward value changes, but the correlation is very weak and not substantial.
#
# Overall, based on these correlation values, it can be concluded that the relationship between Price, Area, and Ward is not very strong. The correlation between Price and Area is the most notable, indicating a modest positive relationship. However, the correlations between Price and Ward, as well as Area and Ward, are very weak, suggesting that they have minimal influence on each other.

# %% [markdown]
# ## Features space visualization

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=BigDS, x='Area', y='Price', hue='Location', legend=None)
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %% [markdown]
# Because of extreme outliers, it's hard to evaluate the distribution of data
